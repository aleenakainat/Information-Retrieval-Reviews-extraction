# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\sana0\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
#df = pd.read_excel (r'Path where the Excel file is stored\File name.xlsx')
df = pd.read_excel (r'D:\Semester 7\IR\Finals\IR_Term_Project\Ecommerce_Rating.xlsx')
# adding an row_id field to the dataframe, which will be useful for joining later
df["row_id"] = df.index + 1
#print first 10 rows 
print (df.head(10))
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0     1671352051-11  https://www.ecommerceceo.com/ecommerce-platforms/
# 1     1671352051-12  https://www.ecommerceceo.com/ecommerce-platforms/
# 2     1671352051-13  https://www.ecommerceceo.com/ecommerce-platforms/
# 3     1671352051-14  https://www.ecommerceceo.com/ecommerce-platforms/
# 4     1671352051-15  https://www.ecommerceceo.com/ecommerce-platforms/
# 5     1671352051-16  https://www.ecommerceceo.com/ecommerce-platforms/
# 6     1671352051-17  https://www.ecommerceceo.com/ecommerce-platforms/
# 7     1671352051-18  https://www.ecommerceceo.com/ecommerce-platforms/
# 8     1671352051-19  https://www.ecommerceceo.com/ecommerce-platforms/
# 9     1671352051-20  https://www.ecommerceceo.com/ecommerce-platforms/
#
#    ProductName                                  Reviews  Ratings  \
# 0      Shopify                        Affordably priced      4.0
# ...

# %%
#create a new data frame with "id" and "comment" fields
df_subset = df[['row_id', 'Reviews']].copy()
#data clean-up
#remove all non-aphabet characters
df_subset['Reviews'] = df_subset['Reviews'].str.replace("[^a-zA-Z#]", " ")
#covert to lower-case
df_subset['Reviews'] = df_subset['Reviews'].str.casefold()
print (df_subset.head(10))
# Out:
#    row_id                                  Reviews
# 0       1                        affordably priced
# 1       2                              easy to use
# 2       3                        nice b b features
# 3       4                 product and sales limits
# 4       5                    limited customization
# 5       6               extensions may need coding
# 6       7                               affordable
# 7       8                      no transaction fees
# 8       9                                 ai tools
# 9      10  fewer template options than competitors
# C:\Users\sana0\AppData\Local\Temp\ipykernel_15660\550806113.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_subset['Reviews'] = df_subset['Reviews'].str.replace("[^a-zA-Z#]", " ")

# %%
# set up empty dataframe for staging output
df1=pd.DataFrame()
df1['row_id']=['99999999999']
df1['sentiment_type']='NA999NA'
df1['sentiment_score']=0

# %%
print('Processing sentiment analysis...')
sid = SentimentIntensityAnalyzer()
t_df = df1
for index, row in df_subset.iterrows():
    scores = sid.polarity_scores(row[1])
    for key, value in scores.items():
        temp = [key,value,row[0]]
        df1['row_id']=row[0]
        df1['sentiment_type']=key
        df1['sentiment_score']=value
        t_df=t_df.append(df1)
#remove dummy row with row_id = 99999999999
t_df_cleaned = t_df[t_df.row_id != '99999999999']
#remove duplicates if any exist
t_df_cleaned = t_df_cleaned.drop_duplicates()
# only keep rows where sentiment_type = compound
t_df_cleaned = t_df[t_df.sentiment_type == 'compound']
print(t_df_cleaned.head(10))
# Out:
# Processing sentiment analysis...
# C:\Users\sana0\AppData\Local\Temp\ipykernel_15660\2795772515.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   t_df=t_df.append(df1)
# C:\Users\sana0\AppData\Local\Temp\ipykernel_15660\2795772515.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   t_df=t_df.append(df1)
# C:\Users\sana0\AppData\Local\Temp\ipykernel_15660\2795772515.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   t_df=t_df.append(df1)
# C:\Users\sana0\AppData\Local\Temp\ipykernel_15660\2795772515.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   t_df=t_df.append(df1)
# ...

# %%
#merge dataframes
df_output = pd.merge(df, t_df_cleaned, on='row_id', how='inner')
print(df_output.head(10))
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0     1671352051-11  https://www.ecommerceceo.com/ecommerce-platforms/
# 1     1671352051-12  https://www.ecommerceceo.com/ecommerce-platforms/
# 2     1671352051-13  https://www.ecommerceceo.com/ecommerce-platforms/
# 3     1671352051-14  https://www.ecommerceceo.com/ecommerce-platforms/
# 4     1671352051-15  https://www.ecommerceceo.com/ecommerce-platforms/
# 5     1671352051-16  https://www.ecommerceceo.com/ecommerce-platforms/
# 6     1671352051-17  https://www.ecommerceceo.com/ecommerce-platforms/
# 7     1671352051-18  https://www.ecommerceceo.com/ecommerce-platforms/
# 8     1671352051-19  https://www.ecommerceceo.com/ecommerce-platforms/
# 9     1671352051-20  https://www.ecommerceceo.com/ecommerce-platforms/
#
#    ProductName                                  Reviews  Ratings  \
# 0      Shopify                        Affordably priced      4.0
# ...

# %%
df_output[["sentiment_score"]].describe()
# Out:
#        sentiment_score
# count        72.000000
# mean          0.079997
# std           0.303730
# min          -0.476700
# 25%          -0.025675
# 50%           0.000000
# 75%           0.350450
# max           0.778300

# %%
#generate mean of sentiment_score by period
dfg = df_output.groupby(['Ratings'])['sentiment_score'].mean()
#create a bar plot
dfg.plot(kind='bar', title='Sentiment Score', ylabel='Mean Sentiment Score',
         xlabel='Ratings', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Sentiment Score'}, xlabel='Ratings', ylabel='Mean Sentiment Score'>

# %%
dfg = df_output.groupby(['ProductName'])['Ratings'].mean()
dfg.plot(kind='bar', title='Website Ratings', ylabel='Ratings',
         xlabel='ProductName', figsize=(6, 5))
# Out:
# <AxesSubplot:title={'center':'Website Ratings'}, xlabel='ProductName', ylabel='Ratings'>
